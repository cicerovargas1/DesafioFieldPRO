# %% [markdown]
# # Biblitecas

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
from numpy import nan
import math
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# # Carregamento de Dados

# %%
df_sensor = pd.read_csv('../raw_data/Sensor_FieldPRO.csv')
df_sensor
# Out:
#             Datetime – utc  air_humidity_100  air_temperature_100  \
# 0     2020-09-30T23:00:00Z              38.0               31.366
# 1     2020-10-01T00:00:00Z               NaN                  NaN
# 2     2020-10-01T01:00:00Z              39.0               31.366
# 3     2020-10-01T02:00:00Z              39.0               31.322
# 4     2020-10-01T03:00:00Z              38.0               31.240
# ...                    ...               ...                  ...
# 1706  2020-12-11T09:00:00Z              82.0               19.480
# 1707  2020-12-11T10:00:00Z              69.0               24.000
# 1708  2020-12-11T11:00:00Z              63.0               25.440
# 1709  2020-12-11T12:00:00Z              60.0               27.160
# 1710  2020-12-11T13:00:00Z              56.0               29.060
#
#       atm_pressure_main  num_of_resets  piezo_charge  piezo_temperature
# 0                  9412              0         45123                 30
# 1                  9412              0         45025                 31
# 2                  9419              0         44923                 31
# 3                  9419              0         44825                 31
# 4                  9416              0         44728                 31
# ...                 ...            ...           ...                ...
# 1706               9422              3         20669                 17
# 1707               9429              3         20606                 19
# 1708               9436              3         20529                 25
# 1709               9439              3         20442                 28
# 1710               9440              3         20344                 30
#
# [1711 rows x 7 columns]

# %% [markdown]
# - piezo_charge: carga do acumulador é medida de hora em hora
#
# - piezo_temperature: temperatura da placa (também medida de hora em hora)
#
# - num_of_resets: número total de resets da placa desde que foi ligada pela primeira vez
#
# OBS.: Um evento de reset na placa pode afetar o comportamento do acumulador de
# carga

# %%
df_estacao = pd.read_csv('../raw_data/Estacao_Convencional.csv')
df_estacao
# Out:
#             data Hora (Brasília)  chuva
# 0     2020-09-01        00:00:00    0.0
# 1     2020-09-01        01:00:00    0.0
# 2     2020-09-01        02:00:00    0.0
# 3     2020-09-01        03:00:00    0.0
# 4     2020-09-01        04:00:00    0.0
# ...          ...             ...    ...
# 2251  2020-12-03        19:00:00    0.0
# 2252  2020-12-03        20:00:00    0.0
# 2253  2020-12-03        21:00:00    0.0
# 2254  2020-12-03        22:00:00    0.0
# 2255  2020-12-03        23:00:00    0.0
#
# [2256 rows x 3 columns]

# %% [markdown]
# # Limpeza e arrumação de dados

# %%
df_sensor.shape
# Out:
# (1711, 7)

# %%
df_sensor.head()
# Out:
#          Datetime – utc  air_humidity_100  air_temperature_100  \
# 0  2020-09-30T23:00:00Z              38.0               31.366
# 1  2020-10-01T00:00:00Z               NaN                  NaN
# 2  2020-10-01T01:00:00Z              39.0               31.366
# 3  2020-10-01T02:00:00Z              39.0               31.322
# 4  2020-10-01T03:00:00Z              38.0               31.240
#
#    atm_pressure_main  num_of_resets  piezo_charge  piezo_temperature
# 0               9412              0         45123                 30
# 1               9412              0         45025                 31
# 2               9419              0         44923                 31
# 3               9419              0         44825                 31
# 4               9416              0         44728                 31

# %%
df_sensor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1711 entries, 0 to 1710
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Datetime – utc       1711 non-null   object
#  1   air_humidity_100     1705 non-null   float64
#  2   air_temperature_100  1705 non-null   float64
#  3   atm_pressure_main    1711 non-null   int64
#  4   num_of_resets        1711 non-null   int64
#  5   piezo_charge         1711 non-null   int64
#  6   piezo_temperature    1711 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 93.7+ KB

# %% [markdown]
# ## Eliminar linhas com valores NaN

# %%
df_sensor.isna().sum()
# Out:
# Datetime – utc         0
# air_humidity_100       6
# air_temperature_100    6
# atm_pressure_main      0
# num_of_resets          0
# piezo_charge           0
# piezo_temperature      0
# dtype: int64

# %%
df_sensor.dropna()
# Out:
#             Datetime – utc  air_humidity_100  air_temperature_100  \
# 0     2020-09-30T23:00:00Z              38.0               31.366
# 2     2020-10-01T01:00:00Z              39.0               31.366
# 3     2020-10-01T02:00:00Z              39.0               31.322
# 4     2020-10-01T03:00:00Z              38.0               31.240
# 5     2020-10-01T04:00:00Z              39.0               30.828
# ...                    ...               ...                  ...
# 1706  2020-12-11T09:00:00Z              82.0               19.480
# 1707  2020-12-11T10:00:00Z              69.0               24.000
# 1708  2020-12-11T11:00:00Z              63.0               25.440
# 1709  2020-12-11T12:00:00Z              60.0               27.160
# 1710  2020-12-11T13:00:00Z              56.0               29.060
#
#       atm_pressure_main  num_of_resets  piezo_charge  piezo_temperature
# 0                  9412              0         45123                 30
# 2                  9419              0         44923                 31
# 3                  9419              0         44825                 31
# 4                  9416              0         44728                 31
# 5                  9411              0         44632                 30
# ...                 ...            ...           ...                ...
# 1706               9422              3         20669                 17
# 1707               9429              3         20606                 19
# 1708               9436              3         20529                 25
# 1709               9439              3         20442                 28
# 1710               9440              3         20344                 30
#
# [1705 rows x 7 columns]

# %%
df_sensor.dropna().reset_index().drop(columns='index')
# Out:
#             Datetime – utc  air_humidity_100  air_temperature_100  \
# 0     2020-09-30T23:00:00Z              38.0               31.366
# 1     2020-10-01T01:00:00Z              39.0               31.366
# 2     2020-10-01T02:00:00Z              39.0               31.322
# 3     2020-10-01T03:00:00Z              38.0               31.240
# 4     2020-10-01T04:00:00Z              39.0               30.828
# ...                    ...               ...                  ...
# 1700  2020-12-11T09:00:00Z              82.0               19.480
# 1701  2020-12-11T10:00:00Z              69.0               24.000
# 1702  2020-12-11T11:00:00Z              63.0               25.440
# 1703  2020-12-11T12:00:00Z              60.0               27.160
# 1704  2020-12-11T13:00:00Z              56.0               29.060
#
#       atm_pressure_main  num_of_resets  piezo_charge  piezo_temperature
# 0                  9412              0         45123                 30
# 1                  9419              0         44923                 31
# 2                  9419              0         44825                 31
# 3                  9416              0         44728                 31
# 4                  9411              0         44632                 30
# ...                 ...            ...           ...                ...
# 1700               9422              3         20669                 17
# 1701               9429              3         20606                 19
# 1702               9436              3         20529                 25
# 1703               9439              3         20442                 28
# 1704               9440              3         20344                 30
#
# [1705 rows x 7 columns]

# %%
df_sensor2 = df_sensor.dropna().reset_index().drop(columns='index')
df_sensor2
# Out:
#             Datetime – utc  air_humidity_100  air_temperature_100  \
# 0     2020-09-30T23:00:00Z              38.0               31.366
# 1     2020-10-01T01:00:00Z              39.0               31.366
# 2     2020-10-01T02:00:00Z              39.0               31.322
# 3     2020-10-01T03:00:00Z              38.0               31.240
# 4     2020-10-01T04:00:00Z              39.0               30.828
# ...                    ...               ...                  ...
# 1700  2020-12-11T09:00:00Z              82.0               19.480
# 1701  2020-12-11T10:00:00Z              69.0               24.000
# 1702  2020-12-11T11:00:00Z              63.0               25.440
# 1703  2020-12-11T12:00:00Z              60.0               27.160
# 1704  2020-12-11T13:00:00Z              56.0               29.060
#
#       atm_pressure_main  num_of_resets  piezo_charge  piezo_temperature
# 0                  9412              0         45123                 30
# 1                  9419              0         44923                 31
# 2                  9419              0         44825                 31
# 3                  9416              0         44728                 31
# 4                  9411              0         44632                 30
# ...                 ...            ...           ...                ...
# 1700               9422              3         20669                 17
# 1701               9429              3         20606                 19
# 1702               9436              3         20529                 25
# 1703               9439              3         20442                 28
# 1704               9440              3         20344                 30
#
# [1705 rows x 7 columns]

# %% [markdown]
# ## Tratar da coluna Datetime - utc

# %%
df_sensor2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705 entries, 0 to 1704
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Datetime – utc       1705 non-null   object
#  1   air_humidity_100     1705 non-null   float64
#  2   air_temperature_100  1705 non-null   float64
#  3   atm_pressure_main    1705 non-null   int64
#  4   num_of_resets        1705 non-null   int64
#  5   piezo_charge         1705 non-null   int64
#  6   piezo_temperature    1705 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 93.4+ KB

# %%
df_sensor2['Datetime – utc'][0]
# Out:
# '2020-09-30T23:00:00Z'

# %%
df_sensor2['Datetime – utc'][0][-1]
# Out:
# 'Z'

# %%
df_sensor2['Datetime – utc'][0][-10]
# Out:
# 'T'

# %%
pd.to_datetime(df_sensor2['Datetime – utc'][0])
# Out:
# Timestamp('2020-09-30 23:00:00+0000', tz='UTC')

# %% [markdown]
# - Retirado de https://stackoverflow.com/questions/59744589/how-can-i-convert-the-string-2020-01-06t000000-000z-into-a-datetime-object

# %%
pd.to_datetime(df_sensor2['Datetime – utc']).dt.tz_localize(None)
# Out:
# 0      2020-09-30 23:00:00
# 1      2020-10-01 01:00:00
# 2      2020-10-01 02:00:00
# 3      2020-10-01 03:00:00
# 4      2020-10-01 04:00:00
#                ...
# 1700   2020-12-11 09:00:00
# 1701   2020-12-11 10:00:00
# 1702   2020-12-11 11:00:00
# 1703   2020-12-11 12:00:00
# 1704   2020-12-11 13:00:00
# Name: Datetime – utc, Length: 1705, dtype: datetime64[ns]

# %%
df_sensor3 = df_sensor2.copy()

# %%
df_sensor3['Datetime – utc'] = pd.to_datetime(df_sensor2['Datetime – utc']).dt.tz_localize(None)

# %%
df_sensor2.head()
# Out:
#          Datetime – utc  air_humidity_100  air_temperature_100  \
# 0  2020-09-30T23:00:00Z              38.0               31.366
# 1  2020-10-01T01:00:00Z              39.0               31.366
# 2  2020-10-01T02:00:00Z              39.0               31.322
# 3  2020-10-01T03:00:00Z              38.0               31.240
# 4  2020-10-01T04:00:00Z              39.0               30.828
#
#    atm_pressure_main  num_of_resets  piezo_charge  piezo_temperature
# 0               9412              0         45123                 30
# 1               9419              0         44923                 31
# 2               9419              0         44825                 31
# 3               9416              0         44728                 31
# 4               9411              0         44632                 30

# %%
df_sensor3.head()
# Out:
#        Datetime – utc  air_humidity_100  air_temperature_100  \
# 0 2020-09-30 23:00:00              38.0               31.366
# 1 2020-10-01 01:00:00              39.0               31.366
# 2 2020-10-01 02:00:00              39.0               31.322
# 3 2020-10-01 03:00:00              38.0               31.240
# 4 2020-10-01 04:00:00              39.0               30.828
#
#    atm_pressure_main  num_of_resets  piezo_charge  piezo_temperature
# 0               9412              0         45123                 30
# 1               9419              0         44923                 31
# 2               9419              0         44825                 31
# 3               9416              0         44728                 31
# 4               9411              0         44632                 30

# %%
df_sensor3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705 entries, 0 to 1704
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Datetime – utc       1705 non-null   datetime64[ns]
#  1   air_humidity_100     1705 non-null   float64
#  2   air_temperature_100  1705 non-null   float64
#  3   atm_pressure_main    1705 non-null   int64
#  4   num_of_resets        1705 non-null   int64
#  5   piezo_charge         1705 non-null   int64
#  6   piezo_temperature    1705 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(4)
# memory usage: 93.4 KB

# %% [markdown]
# ## Juntar colunas data e hora da tabela de estação

# %%
df_estacao
# Out:
#             data Hora (Brasília)  chuva
# 0     2020-09-01        00:00:00    0.0
# 1     2020-09-01        01:00:00    0.0
# 2     2020-09-01        02:00:00    0.0
# 3     2020-09-01        03:00:00    0.0
# 4     2020-09-01        04:00:00    0.0
# ...          ...             ...    ...
# 2251  2020-12-03        19:00:00    0.0
# 2252  2020-12-03        20:00:00    0.0
# 2253  2020-12-03        21:00:00    0.0
# 2254  2020-12-03        22:00:00    0.0
# 2255  2020-12-03        23:00:00    0.0
#
# [2256 rows x 3 columns]

# %%
df_estacao['data - Hora'] = df_estacao['data']+" "+df_estacao['Hora (Brasília)']

# %%
df_estacao
# Out:
#             data Hora (Brasília)  chuva          data - Hora
# 0     2020-09-01        00:00:00    0.0  2020-09-01 00:00:00
# 1     2020-09-01        01:00:00    0.0  2020-09-01 01:00:00
# 2     2020-09-01        02:00:00    0.0  2020-09-01 02:00:00
# 3     2020-09-01        03:00:00    0.0  2020-09-01 03:00:00
# 4     2020-09-01        04:00:00    0.0  2020-09-01 04:00:00
# ...          ...             ...    ...                  ...
# 2251  2020-12-03        19:00:00    0.0  2020-12-03 19:00:00
# 2252  2020-12-03        20:00:00    0.0  2020-12-03 20:00:00
# 2253  2020-12-03        21:00:00    0.0  2020-12-03 21:00:00
# 2254  2020-12-03        22:00:00    0.0  2020-12-03 22:00:00
# 2255  2020-12-03        23:00:00    0.0  2020-12-03 23:00:00
#
# [2256 rows x 4 columns]

# %%
df_estacao2 = df_estacao.copy()

# %%
df_estacao2['data - Hora'] = pd.to_datetime(df_estacao['data - Hora'])

# %%
df_estacao2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2256 entries, 0 to 2255
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   data             2256 non-null   object
#  1   Hora (Brasília)  2256 non-null   object
#  2   chuva            2256 non-null   float64
#  3   data - Hora      2256 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 70.6+ KB

# %%
df_estacao3 = df_estacao2.copy()

# %%
df_estacao3 = df_estacao2.drop(columns=['data', 'Hora (Brasília)'])

# %%
df_estacao2.head()
# Out:
#          data Hora (Brasília)  chuva         data - Hora
# 0  2020-09-01        00:00:00    0.0 2020-09-01 00:00:00
# 1  2020-09-01        01:00:00    0.0 2020-09-01 01:00:00
# 2  2020-09-01        02:00:00    0.0 2020-09-01 02:00:00
# 3  2020-09-01        03:00:00    0.0 2020-09-01 03:00:00
# 4  2020-09-01        04:00:00    0.0 2020-09-01 04:00:00

# %%
df_estacao3.head()
# Out:
#    chuva         data - Hora
# 0    0.0 2020-09-01 00:00:00
# 1    0.0 2020-09-01 01:00:00
# 2    0.0 2020-09-01 02:00:00
# 3    0.0 2020-09-01 03:00:00
# 4    0.0 2020-09-01 04:00:00

# %%
df_estacao2.shape
# Out:
# (2256, 4)

# %%
df_estacao3.shape
# Out:
# (2256, 2)

# %%
df_estacao3['chuva'].value_counts()
# Out:
# 0.0     2192
# 0.2       18
# 0.6        7
# 0.4        5
# 0.8        4
# 1.2        3
# 1.0        2
# 2.2        2
# 9.2        2
# 6.8        2
# 1.6        2
# 6.2        1
# 2.0        1
# 4.6        1
# 3.8        1
# 4.2        1
# 15.2       1
# 3.4        1
# 5.6        1
# 3.6        1
# 16.8       1
# 2.8        1
# 2.4        1
# 1.8        1
# 3.0        1
# 4.0        1
# 2.6        1
# 8.2        1
# Name: chuva, dtype: int64

# %% [markdown]
# ## Mudar nome da coluna Datetime – utc para data - hora

# %%
df_estacao3.head()
# Out:
#    chuva         data - Hora
# 0    0.0 2020-09-01 00:00:00
# 1    0.0 2020-09-01 01:00:00
# 2    0.0 2020-09-01 02:00:00
# 3    0.0 2020-09-01 03:00:00
# 4    0.0 2020-09-01 04:00:00

# %%
df_sensor3.head()
# Out:
#        Datetime – utc  air_humidity_100  air_temperature_100  \
# 0 2020-09-30 23:00:00              38.0               31.366
# 1 2020-10-01 01:00:00              39.0               31.366
# 2 2020-10-01 02:00:00              39.0               31.322
# 3 2020-10-01 03:00:00              38.0               31.240
# 4 2020-10-01 04:00:00              39.0               30.828
#
#    atm_pressure_main  num_of_resets  piezo_charge  piezo_temperature
# 0               9412              0         45123                 30
# 1               9419              0         44923                 31
# 2               9419              0         44825                 31
# 3               9416              0         44728                 31
# 4               9411              0         44632                 30

# %%
df_sensor3.rename({'Datetime – utc': 'data - Hora'}, axis = 'columns', inplace=True)

# %%
df_sensor3.head()
# Out:
#           data - Hora  air_humidity_100  air_temperature_100  \
# 0 2020-09-30 23:00:00              38.0               31.366
# 1 2020-10-01 01:00:00              39.0               31.366
# 2 2020-10-01 02:00:00              39.0               31.322
# 3 2020-10-01 03:00:00              38.0               31.240
# 4 2020-10-01 04:00:00              39.0               30.828
#
#    atm_pressure_main  num_of_resets  piezo_charge  piezo_temperature
# 0               9412              0         45123                 30
# 1               9419              0         44923                 31
# 2               9419              0         44825                 31
# 3               9416              0         44728                 31
# 4               9411              0         44632                 30

# %%
df_sensor3.shape
# Out:
# (1705, 7)

# %%
df_estacao3.shape
# Out:
# (2256, 2)

# %% [markdown]
# ## Ordenar ambas tabelas por data

# %%
df_sensor4 = df_sensor3.sort_values(by='data - Hora')

# %%
df_sensor4
# Out:
#              data - Hora  air_humidity_100  air_temperature_100  \
# 0    2020-09-30 23:00:00              38.0               31.366
# 1    2020-10-01 01:00:00              39.0               31.366
# 2    2020-10-01 02:00:00              39.0               31.322
# 3    2020-10-01 03:00:00              38.0               31.240
# 4    2020-10-01 04:00:00              39.0               30.828
# ...                  ...               ...                  ...
# 1700 2020-12-11 09:00:00              82.0               19.480
# 1701 2020-12-11 10:00:00              69.0               24.000
# 1702 2020-12-11 11:00:00              63.0               25.440
# 1703 2020-12-11 12:00:00              60.0               27.160
# 1704 2020-12-11 13:00:00              56.0               29.060
#
#       atm_pressure_main  num_of_resets  piezo_charge  piezo_temperature
# 0                  9412              0         45123                 30
# 1                  9419              0         44923                 31
# 2                  9419              0         44825                 31
# 3                  9416              0         44728                 31
# 4                  9411              0         44632                 30
# ...                 ...            ...           ...                ...
# 1700               9422              3         20669                 17
# 1701               9429              3         20606                 19
# 1702               9436              3         20529                 25
# 1703               9439              3         20442                 28
# 1704               9440              3         20344                 30
#
# [1705 rows x 7 columns]

# %%
df_estacao4 = df_estacao3.sort_values(by='data - Hora')

# %%
df_estacao4
# Out:
#       chuva         data - Hora
# 0       0.0 2020-09-01 00:00:00
# 1       0.0 2020-09-01 01:00:00
# 2       0.0 2020-09-01 02:00:00
# 3       0.0 2020-09-01 03:00:00
# 4       0.0 2020-09-01 04:00:00
# ...     ...                 ...
# 2251    0.0 2020-12-03 19:00:00
# 2252    0.0 2020-12-03 20:00:00
# 2253    0.0 2020-12-03 21:00:00
# 2254    0.0 2020-12-03 22:00:00
# 2255    0.0 2020-12-03 23:00:00
#
# [2256 rows x 2 columns]

# %%
df_estacao4['data - Hora'].iloc[0]
# Out:
# Timestamp('2020-09-01 00:00:00')

# %%
df_estacao4['data - Hora'].iloc[-1]
# Out:
# Timestamp('2020-12-03 23:00:00')

# %% [markdown]
# - Dados da estação vão de 01/09/2020 até 03/12/2020

# %%
df_sensor4['data - Hora'].iloc[0]
# Out:
# Timestamp('2020-09-30 23:00:00')

# %%
df_sensor4['data - Hora'].iloc[-1]
# Out:
# Timestamp('2020-12-11 13:00:00')

# %% [markdown]
# - Dados do sensor vão de 30/09/2020 até 11/12/2020

# %% [markdown]
# ## Merge
#
# Pensar que só dá pra levar em conta os dados do período em que o sensor está funcionando, então o merge deve ir a

# %%
df_sensor4.merge(df_estacao4)
# Out:
#              data - Hora  air_humidity_100  air_temperature_100  \
# 0    2020-09-30 23:00:00              38.0               31.366
# 1    2020-10-01 01:00:00              39.0               31.366
# 2    2020-10-01 02:00:00              39.0               31.322
# 3    2020-10-01 03:00:00              38.0               31.240
# 4    2020-10-01 04:00:00              39.0               30.828
# ...                  ...               ...                  ...
# 1517 2020-12-03 19:00:00              86.0               20.880
# 1518 2020-12-03 20:00:00              90.0               20.980
# 1519 2020-12-03 21:00:00              93.0               20.620
# 1520 2020-12-03 22:00:00              94.0               20.080
# 1521 2020-12-03 23:00:00              97.0               19.440
#
#       atm_pressure_main  num_of_resets  piezo_charge  piezo_temperature  chuva
# 0                  9412              0         45123                 30    0.0
# 1                  9419              0         44923                 31    0.0
# 2                  9419              0         44825                 31    0.0
# 3                  9416              0         44728                 31    0.0
# 4                  9411              0         44632                 30    0.0
# ...                 ...            ...           ...                ...    ...
# 1517               9412              3         35217                 20    0.0
# 1518               9409              3         35132                 19    0.0
# 1519               9408              3         35068                 20    0.0
# 1520               9406              3         35007                 19    0.0
# 1521               9415              3         34948                 19    0.0
#
# [1522 rows x 8 columns]

# %%
df_sensor4.merge(df_estacao4)['chuva'].value_counts()
# Out:
# 0.0     1467
# 0.2       14
# 0.6        5
# 0.4        4
# 0.8        4
# 1.2        3
# 9.2        2
# 1.6        2
# 2.2        2
# 6.8        2
# 15.2       1
# 3.4        1
# 1.0        1
# 4.6        1
# 3.8        1
# 6.2        1
# 2.0        1
# 2.4        1
# 4.2        1
# 3.6        1
# 16.8       1
# 2.8        1
# 5.6        1
# 1.8        1
# 3.0        1
# 4.0        1
# 8.2        1
# Name: chuva, dtype: int64
